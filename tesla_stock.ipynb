# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
dt=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Tesla.csv')
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2996 entries, 0 to 2995
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2996 non-null   object
#  1   Open       2996 non-null   float64
#  2   High       2996 non-null   float64
#  3   Low        2996 non-null   float64
#  4   Close      2996 non-null   float64
#  5   Adj Close  2996 non-null   float64
#  6   Volume     2996 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 164.0+ KB

# %%
dt.head()
# Out:
#          Date   Open   High    Low  Close  Adj Close    Volume
# 0  2010-06-29  3.800  5.000  3.508  4.778      4.778  93831500
# 1  2010-06-30  5.158  6.084  4.660  4.766      4.766  85935500
# 2  2010-07-01  5.000  5.184  4.054  4.392      4.392  41094000
# 3  2010-07-02  4.600  4.620  3.742  3.840      3.840  25699000
# 4  2010-07-06  4.000  4.000  3.166  3.222      3.222  34334500

# %%
dt.tail()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 2991  2022-05-16  767.159973  769.760010  719.090027  724.369995  724.369995
# 2992  2022-05-17  747.359985  764.479980  728.849976  761.609985  761.609985
# 2993  2022-05-18  744.520020  760.500000  700.809998  709.809998  709.809998
# 2994  2022-05-19  707.000000  734.000000  694.109985  709.419983  709.419983
# 2995  2022-05-20  713.989990  721.580017  633.000000  663.900024  663.900024
#
#         Volume
# 2991  28699500
# 2992  26745400
# 2993  29270600
# 2994  30098900
# 2995  48190600

# %%
dt.describe
# Out:
# <bound method NDFrame.describe of             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-06-29    3.800000    5.000000    3.508000    4.778000    4.778000
# 1     2010-06-30    5.158000    6.084000    4.660000    4.766000    4.766000
# 2     2010-07-01    5.000000    5.184000    4.054000    4.392000    4.392000
# 3     2010-07-02    4.600000    4.620000    3.742000    3.840000    3.840000
# 4     2010-07-06    4.000000    4.000000    3.166000    3.222000    3.222000
# ...          ...         ...         ...         ...         ...         ...
# 2991  2022-05-16  767.159973  769.760010  719.090027  724.369995  724.369995
# 2992  2022-05-17  747.359985  764.479980  728.849976  761.609985  761.609985
# 2993  2022-05-18  744.520020  760.500000  700.809998  709.809998  709.809998
# 2994  2022-05-19  707.000000  734.000000  694.109985  709.419983  709.419983
# 2995  2022-05-20  713.989990  721.580017  633.000000  663.900024  663.900024
#
# ...

# %%
import matplotlib
import matplotlib.pyplot as plt
import plotly.express as px

# %%
dt['High'].value_counts()
# Out:
# 6.900000      7
# 5.600000      7
# 6.000000      7
# 5.400000      6
# 6.960000      5
#              ..
# 44.160000     1
# 47.750000     1
# 7.136000      1
# 46.993999     1
# 721.580017    1
# Name: High, Length: 2700, dtype: int64

# %%
dt['Low'].value_counts()
# Out:
# 5.460000      6
# 5.600000      6
# 40.599998     5
# 4.010000      4
# 5.580000      4
#              ..
# 40.515999     1
# 40.444000     1
# 40.560001     1
# 39.166000     1
# 633.000000    1
# Name: Low, Length: 2711, dtype: int64

# %%
px.scatter(x=dt['High'].value_counts().index,
       y=dt['High'].value_counts())
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.scatter(x=dt['Low'].value_counts().index,
       y=dt['Low'].value_counts())
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
date_hl = dt[['Date','High']]
date_hl
# Out:
#             Date        High
# 0     2010-06-29    5.000000
# 1     2010-06-30    6.084000
# 2     2010-07-01    5.184000
# 3     2010-07-02    4.620000
# 4     2010-07-06    4.000000
# ...          ...         ...
# 2991  2022-05-16  769.760010
# 2992  2022-05-17  764.479980
# 2993  2022-05-18  760.500000
# 2994  2022-05-19  734.000000
# 2995  2022-05-20  721.580017
#
# [2996 rows x 2 columns]

# %%
date_hl = dt[['Date','Low']]
date_hl
# Out:
#             Date         Low
# 0     2010-06-29    3.508000
# 1     2010-06-30    4.660000
# 2     2010-07-01    4.054000
# 3     2010-07-02    3.742000
# 4     2010-07-06    3.166000
# ...          ...         ...
# 2991  2022-05-16  719.090027
# 2992  2022-05-17  728.849976
# 2993  2022-05-18  700.809998
# 2994  2022-05-19  694.109985
# 2995  2022-05-20  633.000000
#
# [2996 rows x 2 columns]

# %%
date_hl = dt[['Date','Close']]
date_hl
# Out:
#             Date       Close
# 0     2010-06-29    4.778000
# 1     2010-06-30    4.766000
# 2     2010-07-01    4.392000
# 3     2010-07-02    3.840000
# 4     2010-07-06    3.222000
# ...          ...         ...
# 2991  2022-05-16  724.369995
# 2992  2022-05-17  761.609985
# 2993  2022-05-18  709.809998
# 2994  2022-05-19  709.419983
# 2995  2022-05-20  663.900024
#
# [2996 rows x 2 columns]

# %%
plt.figure()
plt.scatter(list(date_hl['Date']),list(date_hl['Close']))
plt.show()

# %%
plt.figure()
plt.bar(list(date_hl['Date']),list(date_hl['Close']))
plt.show()
